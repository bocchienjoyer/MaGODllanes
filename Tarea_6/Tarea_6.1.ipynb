# %% [markdown]
# <img src="https://i.imgur.com/OSp7FVO.png"/>
#
# # Tarea 6
#
# ## Ejercicio 1

# %%
strategies=['Rock','Paper','Scissors']

# %%
payoff={('Rock','Paper'):(0,1),
        ('Paper','Rock'):(1,0),
        ('Rock','Scissors'):(1,0),
        ('Scissors','Rock'):(0,1),
        ('Paper','Scissors'):(0,1),
        ('Scissors','Paper'):(1,0),
        ('Rock','Rock'):(0,0),
        ('Paper','Paper'):(0,0),
        ('Scissors','Scissors'):(0,0)}

# %%
# names of players
names=['Jose','Hadaly','Edgar','Charles']

# %%
# setting up players
society=[{'name':n,'score':0,'strategy':None} for n in names]

# %%
# each player a dict:
society
# Out:
# [{'name': 'Jose', 'score': 0, 'strategy': None},
#  {'name': 'Hadaly', 'score': 0, 'strategy': None},
#  {'name': 'Edgar', 'score': 0, 'strategy': None},
#  {'name': 'Charles', 'score': 0, 'strategy': None}]

# %%
import itertools

# pair is a tuple of dicts
for pair in itertools.combinations(society,2):
    print(pair)
# Out:
# ({'name': 'Jose', 'score': 0, 'strategy': None}, {'name': 'Hadaly', 'score': 0, 'strategy': None})
# ({'name': 'Jose', 'score': 0, 'strategy': None}, {'name': 'Edgar', 'score': 0, 'strategy': None})
# ({'name': 'Jose', 'score': 0, 'strategy': None}, {'name': 'Charles', 'score': 0, 'strategy': None})
# ({'name': 'Hadaly', 'score': 0, 'strategy': None}, {'name': 'Edgar', 'score': 0, 'strategy': None})
# ({'name': 'Hadaly', 'score': 0, 'strategy': None}, {'name': 'Charles', 'score': 0, 'strategy': None})
# ({'name': 'Edgar', 'score': 0, 'strategy': None}, {'name': 'Charles', 'score': 0, 'strategy': None})

# %%
import itertools

# each dict
for player1,player2 in itertools.combinations(society,2):
    print(player1,player2)
# Out:
# {'name': 'Jose', 'score': 0, 'strategy': None} {'name': 'Hadaly', 'score': 0, 'strategy': None}
# {'name': 'Jose', 'score': 0, 'strategy': None} {'name': 'Edgar', 'score': 0, 'strategy': None}
# {'name': 'Jose', 'score': 0, 'strategy': None} {'name': 'Charles', 'score': 0, 'strategy': None}
# {'name': 'Hadaly', 'score': 0, 'strategy': None} {'name': 'Edgar', 'score': 0, 'strategy': None}
# {'name': 'Hadaly', 'score': 0, 'strategy': None} {'name': 'Charles', 'score': 0, 'strategy': None}
# {'name': 'Edgar', 'score': 0, 'strategy': None} {'name': 'Charles', 'score': 0, 'strategy': None}

# %%
# resetting society
society=[{'name':n,'score':0,'strategy':None} for n in names]

from random import choice
# several rounds
for aRound in range(100):

    # en each round:
    for player1,player2 in itertools.combinations(society,2):
        # each chooses strategy
        player1['strategy']=choice(strategies)

        player2['strategy']=choice(strategies)

        # result from strategy chosen
        result=payoff[player1['strategy'],player2['strategy']]
        
        # see results on live
        print(player1['name'] + " chose " + player1['strategy'] +" - "+player2['name'] + " chose " + player2['strategy'] )
        if payoff[player1['strategy'],player2['strategy']] == (1,0):
            print(player1['name'] + " won")
        if payoff[player1['strategy'],player2['strategy']] == (0,1):
            print(player2['name'] + " won")
        else:
            print("TIE!")

        # update scores
        player1['score']+=result[0]
        player2['score']+=result[1]

        # give the winner
        socialResults=pd.DataFrame(society)
        winnerScore=socialResults.score.max()
        print(socialResults[socialResults.score==winnerScore])
# Out:
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly      1  Scissors
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#      name  score  strategy
# 1  Hadaly      1  Scissors
# 2   Edgar      1  Scissors
# Jose chose Scissors - Charles chose Rock
# Charles won
#       name  score  strategy
# 1   Hadaly      1  Scissors
# 2    Edgar      1  Scissors
# 3  Charles      1      Rock
# Hadaly chose Rock - Edgar chose Paper
# Edgar won
#     name  score strategy
# 2  Edgar      2    Paper
# Hadaly chose Scissors - Charles chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly      2  Scissors
# 2   Edgar      2     Paper
# Edgar chose Scissors - Charles chose Rock
# Charles won
#       name  score  strategy
# 1   Hadaly      2  Scissors
# 2    Edgar      2  Scissors
# 3  Charles      2      Rock
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly      3    Paper
# Jose chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly      3    Paper
# 2   Edgar      3    Paper
# Jose chose Rock - Charles chose Paper
# Charles won
#       name  score strategy
# 1   Hadaly      3    Paper
# 2    Edgar      3    Paper
# 3  Charles      3    Paper
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#       name  score strategy
# 1   Hadaly      3     Rock
# 2    Edgar      3     Rock
# 3  Charles      3    Paper
# Hadaly chose Scissors - Charles chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly      4  Scissors
# Edgar chose Paper - Charles chose Scissors
# Charles won
#       name  score  strategy
# 1   Hadaly      4  Scissors
# 3  Charles      4  Scissors
# Jose chose Scissors - Hadaly chose Rock
# Hadaly won
#      name  score strategy
# 1  Hadaly      5     Rock
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly      5     Rock
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly      5     Rock
# Hadaly chose Paper - Edgar chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly      6    Paper
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly      6    Paper
# Edgar chose Scissors - Charles chose Paper
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly      6    Paper
# Jose chose Rock - Hadaly chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly      6     Rock
# Jose chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly      6     Rock
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly      6     Rock
# Hadaly chose Paper - Edgar chose Scissors
# Edgar won
#      name  score  strategy
# 1  Hadaly      6     Paper
# 2   Edgar      6  Scissors
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#       name  score  strategy
# 1   Hadaly      6     Paper
# 2    Edgar      6  Scissors
# 3  Charles      6  Scissors
# Edgar chose Rock - Charles chose Rock
# TIE!
#       name  score strategy
# 1   Hadaly      6    Paper
# 2    Edgar      6     Rock
# 3  Charles      6     Rock
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly      7    Paper
# Jose chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly      7    Paper
# 2   Edgar      7    Paper
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly      7    Paper
# 2   Edgar      7    Paper
# Hadaly chose Paper - Edgar chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly      8    Paper
# Hadaly chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly      8     Rock
# Edgar chose Paper - Charles chose Scissors
# Charles won
#       name  score  strategy
# 1   Hadaly      8      Rock
# 3  Charles      8  Scissors
# Jose chose Scissors - Hadaly chose Scissors
# TIE!
#       name  score  strategy
# 1   Hadaly      8  Scissors
# 3  Charles      8  Scissors
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#       name  score  strategy
# 1   Hadaly      8  Scissors
# 3  Charles      8  Scissors
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#       name  score  strategy
# 1   Hadaly      8  Scissors
# 3  Charles      8      Rock
# Hadaly chose Paper - Edgar chose Paper
# TIE!
#       name  score strategy
# 1   Hadaly      8    Paper
# 3  Charles      8     Rock
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly      9    Paper
# Edgar chose Paper - Charles chose Scissors
# Charles won
#       name  score  strategy
# 1   Hadaly      9     Paper
# 3  Charles      9  Scissors
# Jose chose Scissors - Hadaly chose Rock
# Hadaly won
#      name  score strategy
# 1  Hadaly     10     Rock
# Jose chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     10     Rock
# Jose chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     10     Rock
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     10  Scissors
# Hadaly chose Scissors - Charles chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     11  Scissors
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score  strategy
# 1  Hadaly     11  Scissors
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     12  Scissors
# Jose chose Paper - Edgar chose Paper
# TIE!
#      name  score  strategy
# 1  Hadaly     12  Scissors
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     12  Scissors
# Hadaly chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     12     Rock
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     13    Paper
# Edgar chose Scissors - Charles chose Paper
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     13    Paper
# Jose chose Scissors - Hadaly chose Rock
# Hadaly won
#      name  score strategy
# 1  Hadaly     14     Rock
# Jose chose Paper - Edgar chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     14     Rock
# Jose chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     14     Rock
# Hadaly chose Rock - Edgar chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     15     Rock
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     16    Paper
# Edgar chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly     16    Paper
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     17    Paper
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#      name  score strategy
# 1  Hadaly     17    Paper
# Jose chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     17    Paper
# Hadaly chose Scissors - Edgar chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     17  Scissors
# Hadaly chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     17     Rock
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     17     Rock
# Jose chose Paper - Hadaly chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     17     Rock
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     17     Rock
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     17     Rock
# Hadaly chose Rock - Edgar chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     18     Rock
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     18  Scissors
# Edgar chose Scissors - Charles chose Rock
# Charles won
#      name  score  strategy
# 1  Hadaly     18  Scissors
# Jose chose Paper - Hadaly chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     18    Paper
# Jose chose Paper - Edgar chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     18    Paper
# Jose chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     18    Paper
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     18     Rock
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     19    Paper
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     19    Paper
# Jose chose Paper - Hadaly chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     19     Rock
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#      name  score strategy
# 1  Hadaly     19     Rock
# Jose chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     19     Rock
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     19     Rock
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     19    Paper
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     19    Paper
# Jose chose Scissors - Hadaly chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     19  Scissors
# Jose chose Paper - Edgar chose Paper
# TIE!
#      name  score  strategy
# 1  Hadaly     19  Scissors
# Jose chose Rock - Charles chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     19  Scissors
# Hadaly chose Scissors - Edgar chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     19  Scissors
# Hadaly chose Scissors - Charles chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     20  Scissors
# Edgar chose Paper - Charles chose Paper
# TIE!
#      name  score  strategy
# 1  Hadaly     20  Scissors
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     21  Scissors
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score  strategy
# 1  Hadaly     21  Scissors
# Jose chose Rock - Charles chose Rock
# TIE!
#      name  score  strategy
# 1  Hadaly     21  Scissors
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     21     Rock
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     21     Rock
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     21     Rock
# Jose chose Scissors - Hadaly chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     21    Paper
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     21    Paper
# Jose chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     21    Paper
# Hadaly chose Paper - Edgar chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     22    Paper
# Hadaly chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     22     Rock
# Edgar chose Paper - Charles chose Rock
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     22     Rock
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     23    Paper
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     23    Paper
# Jose chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     23    Paper
# Hadaly chose Scissors - Edgar chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     24  Scissors
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     24    Paper
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     24    Paper
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     25  Scissors
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     25  Scissors
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     25  Scissors
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     25     Rock
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     26    Paper
# Edgar chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     26    Paper
# Jose chose Scissors - Hadaly chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     26    Paper
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#      name  score strategy
# 1  Hadaly     26    Paper
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     26    Paper
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     26  Scissors
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     26     Rock
# Edgar chose Paper - Charles chose Rock
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     26     Rock
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     27    Paper
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#      name  score strategy
# 1  Hadaly     27    Paper
# Jose chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     27    Paper
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     27  Scissors
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     27  Scissors
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score  strategy
# 1  Hadaly     27  Scissors
# Jose chose Scissors - Hadaly chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     27    Paper
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     27    Paper
# Jose chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     27    Paper
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     27  Scissors
# Hadaly chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     27     Rock
# Edgar chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly     27     Rock
# Jose chose Rock - Hadaly chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     27     Rock
# Jose chose Paper - Edgar chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     27     Rock
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     27     Rock
# Hadaly chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     27     Rock
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     27    Paper
# Edgar chose Scissors - Charles chose Paper
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     27    Paper
# Jose chose Paper - Hadaly chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     27    Paper
# Jose chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     27    Paper
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     27    Paper
# Hadaly chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     27     Rock
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     27    Paper
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     27    Paper
# 2   Edgar     27     Rock
# Jose chose Rock - Hadaly chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     27     Rock
# 2   Edgar     27     Rock
# Jose chose Paper - Edgar chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     27     Rock
# 2   Edgar     27     Rock
# Jose chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     27     Rock
# 2   Edgar     27     Rock
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#     name  score strategy
# 2  Edgar     28     Rock
# Hadaly chose Rock - Charles chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     28     Rock
# 2   Edgar     28     Rock
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     28     Rock
# 2   Edgar     28     Rock
# Jose chose Scissors - Hadaly chose Rock
# Hadaly won
#      name  score strategy
# 1  Hadaly     29     Rock
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     29     Rock
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     29     Rock
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     29     Rock
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     29    Paper
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     29    Paper
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     30  Scissors
# Jose chose Paper - Edgar chose Rock
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     30  Scissors
# Jose chose Rock - Charles chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     30  Scissors
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     30     Rock
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     30     Rock
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     30     Rock
# Jose chose Scissors - Hadaly chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     30    Paper
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#      name  score strategy
# 1  Hadaly     30    Paper
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     30    Paper
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     30     Rock
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     30    Paper
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     30    Paper
# 2   Edgar     30     Rock
# Jose chose Paper - Hadaly chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     30     Rock
# 2   Edgar     30     Rock
# Jose chose Rock - Edgar chose Paper
# Edgar won
#     name  score strategy
# 2  Edgar     31    Paper
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#     name  score strategy
# 2  Edgar     31    Paper
# Hadaly chose Scissors - Edgar chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     31  Scissors
# 2   Edgar     31     Paper
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     31     Rock
# 2   Edgar     31    Paper
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     31      Rock
# 2   Edgar     31  Scissors
# Jose chose Rock - Hadaly chose Rock
# TIE!
#      name  score  strategy
# 1  Hadaly     31      Rock
# 2   Edgar     31  Scissors
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     31      Rock
# 2   Edgar     31  Scissors
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     31      Rock
# 2   Edgar     31  Scissors
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#     name  score strategy
# 2  Edgar     32     Rock
# Hadaly chose Rock - Charles chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     32     Rock
# 2   Edgar     32     Rock
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     32     Rock
# 2   Edgar     32    Paper
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     33  Scissors
# Jose chose Paper - Edgar chose Rock
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     33  Scissors
# Jose chose Scissors - Charles chose Rock
# Charles won
#      name  score  strategy
# 1  Hadaly     33  Scissors
# Hadaly chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     33     Rock
# 2   Edgar     33    Paper
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     33  Scissors
# 2   Edgar     33     Paper
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     33  Scissors
# 2   Edgar     33  Scissors
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     34    Paper
# Jose chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     34    Paper
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     34    Paper
# Hadaly chose Scissors - Edgar chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     35  Scissors
# Hadaly chose Scissors - Charles chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     36  Scissors
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score  strategy
# 1  Hadaly     36  Scissors
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     37  Scissors
# Jose chose Rock - Edgar chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     37  Scissors
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     37  Scissors
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     37     Rock
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     37    Paper
# Edgar chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly     37    Paper
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     38    Paper
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     38    Paper
# Jose chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     38    Paper
# Hadaly chose Scissors - Edgar chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     38  Scissors
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     38    Paper
# Edgar chose Paper - Charles chose Rock
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     38    Paper
# Jose chose Scissors - Hadaly chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     38    Paper
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#      name  score strategy
# 1  Hadaly     38    Paper
# Jose chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     38    Paper
# Hadaly chose Paper - Edgar chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     39    Paper
# Hadaly chose Scissors - Charles chose Rock
# Charles won
#      name  score  strategy
# 1  Hadaly     39  Scissors
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     39  Scissors
# Jose chose Scissors - Hadaly chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     39  Scissors
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score  strategy
# 1  Hadaly     39  Scissors
# Jose chose Rock - Charles chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     39  Scissors
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     39  Scissors
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     39    Paper
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     39    Paper
# Jose chose Scissors - Hadaly chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     39    Paper
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#      name  score strategy
# 1  Hadaly     39    Paper
# Jose chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     39    Paper
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     39  Scissors
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     40    Paper
# Edgar chose Paper - Charles chose Rock
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     40    Paper
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     41  Scissors
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     41  Scissors
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     41  Scissors
# Hadaly chose Paper - Edgar chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     42    Paper
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     42     Rock
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     42     Rock
# Jose chose Rock - Hadaly chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     42  Scissors
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     42  Scissors
# Jose chose Paper - Charles chose Scissors
# Charles won
#      name  score  strategy
# 1  Hadaly     42  Scissors
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     42  Scissors
# 2   Edgar     42      Rock
# Hadaly chose Scissors - Charles chose Rock
# Charles won
#      name  score  strategy
# 1  Hadaly     42  Scissors
# 2   Edgar     42      Rock
# Edgar chose Paper - Charles chose Paper
# TIE!
#      name  score  strategy
# 1  Hadaly     42  Scissors
# 2   Edgar     42     Paper
# Jose chose Paper - Hadaly chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     42     Rock
# 2   Edgar     42    Paper
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     42     Rock
# 2   Edgar     42    Paper
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     42     Rock
# 2   Edgar     42    Paper
# Hadaly chose Paper - Edgar chose Scissors
# Edgar won
#     name  score  strategy
# 2  Edgar     43  Scissors
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#     name  score  strategy
# 2  Edgar     43  Scissors
# Edgar chose Scissors - Charles chose Paper
# Edgar won
# TIE!
#     name  score  strategy
# 2  Edgar     44  Scissors
# Jose chose Rock - Hadaly chose Rock
# TIE!
#     name  score  strategy
# 2  Edgar     44  Scissors
# Jose chose Rock - Edgar chose Paper
# Edgar won
#     name  score strategy
# 2  Edgar     45    Paper
# Jose chose Scissors - Charles chose Scissors
# TIE!
#     name  score strategy
# 2  Edgar     45    Paper
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     45     Rock
# Hadaly chose Rock - Charles chose Paper
# Charles won
#     name  score strategy
# 2  Edgar     45     Rock
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#     name  score strategy
# 2  Edgar     46     Rock
# Jose chose Rock - Hadaly chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     46     Rock
# Jose chose Rock - Edgar chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     46     Rock
# Jose chose Paper - Charles chose Paper
# TIE!
#     name  score strategy
# 2  Edgar     46     Rock
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#     name  score strategy
# 2  Edgar     47     Rock
# Hadaly chose Rock - Charles chose Scissors
# Hadaly won
# TIE!
#     name  score strategy
# 2  Edgar     47     Rock
# Edgar chose Rock - Charles chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     47     Rock
# Jose chose Rock - Hadaly chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     47     Rock
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#     name  score  strategy
# 2  Edgar     48  Scissors
# Jose chose Paper - Charles chose Paper
# TIE!
#     name  score  strategy
# 2  Edgar     48  Scissors
# Hadaly chose Paper - Edgar chose Scissors
# Edgar won
#     name  score  strategy
# 2  Edgar     49  Scissors
# Hadaly chose Rock - Charles chose Rock
# TIE!
#     name  score  strategy
# 2  Edgar     49  Scissors
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#     name  score  strategy
# 2  Edgar     49  Scissors
# Jose chose Rock - Hadaly chose Rock
# TIE!
#     name  score  strategy
# 2  Edgar     49  Scissors
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#     name  score strategy
# 2  Edgar     50     Rock
# Jose chose Paper - Charles chose Scissors
# Charles won
#     name  score strategy
# 2  Edgar     50     Rock
# Hadaly chose Paper - Edgar chose Rock
# Hadaly won
# TIE!
#     name  score strategy
# 2  Edgar     50     Rock
# Hadaly chose Paper - Charles chose Paper
# TIE!
#     name  score strategy
# 2  Edgar     50     Rock
# Edgar chose Rock - Charles chose Paper
# Charles won
#     name  score strategy
# 2  Edgar     50     Rock
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#     name  score strategy
# 2  Edgar     50     Rock
# Jose chose Rock - Edgar chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     50     Rock
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#     name  score strategy
# 2  Edgar     50     Rock
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#     name  score strategy
# 2  Edgar     51     Rock
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#     name  score strategy
# 2  Edgar     51     Rock
# Edgar chose Paper - Charles chose Scissors
# Charles won
#     name  score strategy
# 2  Edgar     51    Paper
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#     name  score strategy
# 2  Edgar     51    Paper
# Jose chose Rock - Edgar chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     51     Rock
# Jose chose Rock - Charles chose Scissors
# Jose won
# TIE!
#     name  score strategy
# 2  Edgar     51     Rock
# Hadaly chose Rock - Edgar chose Scissors
# Hadaly won
# TIE!
#     name  score  strategy
# 2  Edgar     51  Scissors
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#     name  score  strategy
# 2  Edgar     51  Scissors
# Edgar chose Rock - Charles chose Paper
# Charles won
#     name  score strategy
# 2  Edgar     51     Rock
# Jose chose Scissors - Hadaly chose Paper
# Jose won
# TIE!
#     name  score strategy
# 2  Edgar     51     Rock
# Jose chose Rock - Edgar chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     51     Rock
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#     name  score strategy
# 2  Edgar     51     Rock
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     51     Rock
# Hadaly chose Rock - Charles chose Paper
# Charles won
#     name  score strategy
# 2  Edgar     51     Rock
# Edgar chose Paper - Charles chose Rock
# Edgar won
# TIE!
#     name  score strategy
# 2  Edgar     52    Paper
# Jose chose Paper - Hadaly chose Rock
# Jose won
# TIE!
#     name  score strategy
# 2  Edgar     52    Paper
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#     name  score  strategy
# 2  Edgar     52  Scissors
# Jose chose Scissors - Charles chose Scissors
# TIE!
#     name  score  strategy
# 2  Edgar     52  Scissors
# Hadaly chose Paper - Edgar chose Scissors
# Edgar won
#     name  score  strategy
# 2  Edgar     53  Scissors
# Hadaly chose Rock - Charles chose Scissors
# Hadaly won
# TIE!
#     name  score  strategy
# 2  Edgar     53  Scissors
# Edgar chose Paper - Charles chose Rock
# Edgar won
# TIE!
#     name  score strategy
# 2  Edgar     54    Paper
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#     name  score strategy
# 2  Edgar     54    Paper
# Jose chose Rock - Edgar chose Paper
# Edgar won
#     name  score strategy
# 2  Edgar     55    Paper
# Jose chose Scissors - Charles chose Rock
# Charles won
#     name  score strategy
# 2  Edgar     55    Paper
# Hadaly chose Paper - Edgar chose Paper
# TIE!
#     name  score strategy
# 2  Edgar     55    Paper
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#     name  score strategy
# 2  Edgar     55    Paper
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#     name  score  strategy
# 2  Edgar     55  Scissors
# Jose chose Paper - Hadaly chose Rock
# Jose won
# TIE!
#     name  score  strategy
# 2  Edgar     55  Scissors
# Jose chose Paper - Edgar chose Paper
# TIE!
#     name  score strategy
# 2  Edgar     55    Paper
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#     name  score strategy
# 2  Edgar     55    Paper
# Hadaly chose Rock - Edgar chose Paper
# Edgar won
#     name  score strategy
# 2  Edgar     56    Paper
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#     name  score strategy
# 2  Edgar     56    Paper
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#     name  score  strategy
# 2  Edgar     56  Scissors
# Jose chose Scissors - Hadaly chose Paper
# Jose won
# TIE!
#     name  score  strategy
# 2  Edgar     56  Scissors
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#     name  score  strategy
# 2  Edgar     57  Scissors
# Jose chose Scissors - Charles chose Rock
# Charles won
#     name  score  strategy
# 2  Edgar     57  Scissors
# Hadaly chose Scissors - Edgar chose Scissors
# TIE!
#     name  score  strategy
# 2  Edgar     57  Scissors
# Hadaly chose Paper - Charles chose Paper
# TIE!
#     name  score  strategy
# 2  Edgar     57  Scissors
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#     name  score  strategy
# 2  Edgar     57  Scissors
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#     name  score  strategy
# 2  Edgar     57  Scissors
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#     name  score  strategy
# 2  Edgar     57  Scissors
# Jose chose Scissors - Charles chose Rock
# Charles won
#     name  score  strategy
# 2  Edgar     57  Scissors
# Hadaly chose Scissors - Edgar chose Paper
# Hadaly won
# TIE!
#     name  score strategy
# 2  Edgar     57    Paper
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#     name  score strategy
# 2  Edgar     57    Paper
# Edgar chose Paper - Charles chose Scissors
# Charles won
#     name  score strategy
# 2  Edgar     57    Paper
# Jose chose Rock - Hadaly chose Scissors
# Jose won
# TIE!
#     name  score strategy
# 2  Edgar     57    Paper
# Jose chose Rock - Edgar chose Scissors
# Jose won
# TIE!
#     name  score  strategy
# 2  Edgar     57  Scissors
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#     name  score  strategy
# 2  Edgar     57  Scissors
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     57     Rock
# Hadaly chose Rock - Charles chose Rock
# TIE!
#     name  score strategy
# 2  Edgar     57     Rock
# Edgar chose Paper - Charles chose Scissors
# Charles won
#     name  score strategy
# 2  Edgar     57    Paper
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#     name  score strategy
# 2  Edgar     57    Paper
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#     name  score  strategy
# 2  Edgar     57  Scissors
# Jose chose Paper - Charles chose Scissors
# Charles won
#     name  score  strategy
# 2  Edgar     57  Scissors
# Hadaly chose Paper - Edgar chose Paper
# TIE!
#     name  score strategy
# 2  Edgar     57    Paper
# Hadaly chose Scissors - Charles chose Paper
# Hadaly won
# TIE!
#     name  score strategy
# 2  Edgar     57    Paper
# Edgar chose Paper - Charles chose Paper
# TIE!
#     name  score strategy
# 2  Edgar     57    Paper
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#     name  score strategy
# 2  Edgar     57    Paper
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#     name  score  strategy
# 2  Edgar     57  Scissors
# Jose chose Rock - Charles chose Rock
# TIE!
#     name  score  strategy
# 2  Edgar     57  Scissors
# Hadaly chose Scissors - Edgar chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     57  Scissors
# 2   Edgar     57     Paper
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     57  Scissors
# 2   Edgar     57     Paper
# Edgar chose Rock - Charles chose Paper
# Charles won
#      name  score  strategy
# 1  Hadaly     57  Scissors
# 2   Edgar     57      Rock
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     58  Scissors
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#      name  score  strategy
# 1  Hadaly     58  Scissors
# 2   Edgar     58  Scissors
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     58  Scissors
# 2   Edgar     58  Scissors
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     58     Rock
# 2   Edgar     58     Rock
# Hadaly chose Scissors - Charles chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     59  Scissors
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score  strategy
# 1  Hadaly     59  Scissors
# 2   Edgar     59      Rock
# Jose chose Scissors - Hadaly chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     59  Scissors
# 2   Edgar     59      Rock
# Jose chose Rock - Edgar chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     59  Scissors
# 2   Edgar     59  Scissors
# Jose chose Rock - Charles chose Rock
# TIE!
#      name  score  strategy
# 1  Hadaly     59  Scissors
# 2   Edgar     59  Scissors
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#     name  score strategy
# 2  Edgar     60     Rock
# Hadaly chose Scissors - Charles chose Rock
# Charles won
#     name  score strategy
# 2  Edgar     60     Rock
# Edgar chose Rock - Charles chose Paper
# Charles won
#     name  score strategy
# 2  Edgar     60     Rock
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     60    Paper
# 2   Edgar     60     Rock
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     60    Paper
# 2   Edgar     60     Rock
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     60    Paper
# 2   Edgar     60     Rock
# Hadaly chose Rock - Edgar chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     61     Rock
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     61    Paper
# Edgar chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     61    Paper
# Jose chose Paper - Hadaly chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     61    Paper
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     61    Paper
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     61    Paper
# Hadaly chose Scissors - Edgar chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     62  Scissors
# Hadaly chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     62     Rock
# Edgar chose Scissors - Charles chose Paper
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     62     Rock
# Jose chose Paper - Hadaly chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     62     Rock
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     62     Rock
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     62     Rock
# Hadaly chose Paper - Edgar chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     63    Paper
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     63  Scissors
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score  strategy
# 1  Hadaly     63  Scissors
# Jose chose Scissors - Hadaly chose Rock
# Hadaly won
#      name  score strategy
# 1  Hadaly     64     Rock
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     64     Rock
# Jose chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     64     Rock
# Hadaly chose Rock - Edgar chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     65     Rock
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     66    Paper
# Edgar chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly     66    Paper
# Jose chose Paper - Hadaly chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     66     Rock
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     66     Rock
# Jose chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     66     Rock
# Hadaly chose Scissors - Edgar chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     66  Scissors
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     66    Paper
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     66    Paper
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     67    Paper
# Jose chose Paper - Edgar chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     67    Paper
# Jose chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly     67    Paper
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     67  Scissors
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     67  Scissors
# Edgar chose Rock - Charles chose Paper
# Charles won
#      name  score  strategy
# 1  Hadaly     67  Scissors
# Jose chose Scissors - Hadaly chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     67    Paper
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     67    Paper
# Jose chose Rock - Charles chose Scissors
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     67    Paper
# Hadaly chose Paper - Edgar chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     68    Paper
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     69    Paper
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     69    Paper
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     70  Scissors
# Jose chose Rock - Edgar chose Paper
# Edgar won
#      name  score  strategy
# 1  Hadaly     70  Scissors
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     70  Scissors
# Hadaly chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     70    Paper
# Hadaly chose Rock - Charles chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     71     Rock
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     71     Rock
# Jose chose Paper - Hadaly chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     71     Rock
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#      name  score strategy
# 1  Hadaly     71     Rock
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     71     Rock
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     71     Rock
# Hadaly chose Rock - Charles chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     72     Rock
# Edgar chose Scissors - Charles chose Paper
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     72     Rock
# Jose chose Scissors - Hadaly chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     72  Scissors
# Jose chose Rock - Edgar chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     72  Scissors
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     72  Scissors
# Hadaly chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     72    Paper
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     73    Paper
# Edgar chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly     73    Paper
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     74    Paper
# Jose chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     74    Paper
# Jose chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     74    Paper
# Hadaly chose Scissors - Edgar chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     74  Scissors
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     74    Paper
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     74    Paper
# Jose chose Rock - Hadaly chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     74  Scissors
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     74  Scissors
# Jose chose Rock - Charles chose Paper
# Charles won
#      name  score  strategy
# 1  Hadaly     74  Scissors
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     74  Scissors
# Hadaly chose Scissors - Charles chose Rock
# Charles won
#      name  score  strategy
# 1  Hadaly     74  Scissors
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     74  Scissors
# Jose chose Paper - Hadaly chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     74     Rock
# Jose chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     74     Rock
# Jose chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly     74     Rock
# Hadaly chose Rock - Edgar chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     75     Rock
# Hadaly chose Scissors - Charles chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     76  Scissors
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score  strategy
# 1  Hadaly     76  Scissors
# Jose chose Paper - Hadaly chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     76    Paper
# Jose chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     76    Paper
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     76    Paper
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     76  Scissors
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     76    Paper
# Edgar chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     76    Paper
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     77    Paper
# Jose chose Paper - Edgar chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     77    Paper
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     77    Paper
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     77     Rock
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     77     Rock
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     77     Rock
# Jose chose Rock - Hadaly chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     77  Scissors
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score  strategy
# 1  Hadaly     77  Scissors
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     77  Scissors
# Hadaly chose Rock - Edgar chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     78     Rock
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     78  Scissors
# Edgar chose Scissors - Charles chose Paper
# Edgar won
# TIE!
#      name  score  strategy
# 1  Hadaly     78  Scissors
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     79  Scissors
# Jose chose Rock - Edgar chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     79  Scissors
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     79  Scissors
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     79  Scissors
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     79    Paper
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     79    Paper
# Jose chose Scissors - Hadaly chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     79  Scissors
# Jose chose Rock - Edgar chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     79  Scissors
# Jose chose Paper - Charles chose Paper
# TIE!
#      name  score  strategy
# 1  Hadaly     79  Scissors
# Hadaly chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     79     Rock
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     79    Paper
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     79    Paper
# Jose chose Rock - Hadaly chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     79     Rock
# Jose chose Rock - Edgar chose Scissors
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     79     Rock
# Jose chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     79     Rock
# Hadaly chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     79    Paper
# Hadaly chose Rock - Charles chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     80     Rock
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     80     Rock
# Jose chose Scissors - Hadaly chose Rock
# Hadaly won
#      name  score strategy
# 1  Hadaly     81     Rock
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#      name  score strategy
# 1  Hadaly     81     Rock
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     81     Rock
# Hadaly chose Scissors - Edgar chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     82  Scissors
# Hadaly chose Rock - Charles chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     83     Rock
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     83     Rock
# Jose chose Rock - Hadaly chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     83     Rock
# Jose chose Rock - Edgar chose Scissors
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     83     Rock
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     83     Rock
# Hadaly chose Paper - Edgar chose Scissors
# Edgar won
#      name  score strategy
# 1  Hadaly     83    Paper
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     83    Paper
# Edgar chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     83    Paper
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     84  Scissors
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     84  Scissors
# Jose chose Rock - Charles chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     84  Scissors
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     84     Rock
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     84     Rock
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     84     Rock
# Jose chose Scissors - Hadaly chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     84    Paper
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#      name  score strategy
# 1  Hadaly     84    Paper
# Jose chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     84    Paper
# Hadaly chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     84     Rock
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     84     Rock
# Edgar chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly     84     Rock
# Jose chose Rock - Hadaly chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     84  Scissors
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#      name  score  strategy
# 1  Hadaly     84  Scissors
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     84  Scissors
# Hadaly chose Paper - Edgar chose Scissors
# Edgar won
#      name  score strategy
# 1  Hadaly     84    Paper
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     84  Scissors
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     84  Scissors
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     85    Paper
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     85    Paper
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     85    Paper
# Hadaly chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     85    Paper
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     85  Scissors
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score  strategy
# 1  Hadaly     85  Scissors
# Jose chose Rock - Hadaly chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     85     Rock
# Jose chose Paper - Edgar chose Rock
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     85     Rock
# Jose chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     85     Rock
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     85     Rock
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     86    Paper
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     86    Paper
# Jose chose Scissors - Hadaly chose Rock
# Hadaly won
#      name  score strategy
# 1  Hadaly     87     Rock
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     87     Rock
# Jose chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     87     Rock
# Hadaly chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     87    Paper
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     87    Paper
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     87    Paper
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     88  Scissors
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#      name  score  strategy
# 1  Hadaly     88  Scissors
# Jose chose Scissors - Charles chose Rock
# Charles won
#      name  score  strategy
# 1  Hadaly     88  Scissors
# Hadaly chose Paper - Edgar chose Scissors
# Edgar won
#      name  score strategy
# 1  Hadaly     88    Paper
# Hadaly chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     88  Scissors
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score  strategy
# 1  Hadaly     88  Scissors
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly     89  Scissors
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     89  Scissors
# Jose chose Scissors - Charles chose Rock
# Charles won
#      name  score  strategy
# 1  Hadaly     89  Scissors
# Hadaly chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     89    Paper
# Hadaly chose Scissors - Charles chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     90  Scissors
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score  strategy
# 1  Hadaly     90  Scissors
# Jose chose Rock - Hadaly chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     90     Rock
# Jose chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     90     Rock
# Jose chose Rock - Charles chose Scissors
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     90     Rock
# Hadaly chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     90     Rock
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     90     Rock
# Edgar chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly     90     Rock
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly     91    Paper
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     91    Paper
# Jose chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     91    Paper
# Hadaly chose Paper - Edgar chose Scissors
# Edgar won
#      name  score strategy
# 1  Hadaly     91    Paper
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     92    Paper
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     92    Paper
# Jose chose Scissors - Hadaly chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     92  Scissors
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#      name  score  strategy
# 1  Hadaly     92  Scissors
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     92  Scissors
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     92  Scissors
# Hadaly chose Scissors - Charles chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     93  Scissors
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score  strategy
# 1  Hadaly     93  Scissors
# Jose chose Rock - Hadaly chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     93  Scissors
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     93  Scissors
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     93  Scissors
# Hadaly chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     93    Paper
# Hadaly chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     93     Rock
# Edgar chose Scissors - Charles chose Scissors
# TIE!
#      name  score strategy
# 1  Hadaly     93     Rock
# Jose chose Scissors - Hadaly chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     93  Scissors
# Jose chose Scissors - Edgar chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     93  Scissors
# Jose chose Rock - Charles chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     93  Scissors
# Hadaly chose Rock - Edgar chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     94     Rock
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     95    Paper
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     95    Paper
# Jose chose Scissors - Hadaly chose Rock
# Hadaly won
#      name  score strategy
# 1  Hadaly     96     Rock
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     96     Rock
# Jose chose Rock - Charles chose Scissors
# Jose won
# TIE!
#      name  score strategy
# 1  Hadaly     96     Rock
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     96     Rock
# Hadaly chose Rock - Charles chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     97     Rock
# Edgar chose Scissors - Charles chose Paper
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     97     Rock
# Jose chose Rock - Hadaly chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     97     Rock
# Jose chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     97     Rock
# Jose chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     97     Rock
# Hadaly chose Paper - Edgar chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly     98    Paper
# Hadaly chose Scissors - Charles chose Rock
# Charles won
#      name  score  strategy
# 1  Hadaly     98  Scissors
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score  strategy
# 1  Hadaly     98  Scissors
# Jose chose Rock - Hadaly chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     98  Scissors
# Jose chose Scissors - Edgar chose Paper
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     98  Scissors
# Jose chose Scissors - Charles chose Paper
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     98  Scissors
# Hadaly chose Rock - Edgar chose Paper
# Edgar won
#      name  score strategy
# 1  Hadaly     98     Rock
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     98     Rock
# Edgar chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     98     Rock
# Jose chose Paper - Hadaly chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly     98    Paper
# Jose chose Paper - Edgar chose Scissors
# Edgar won
#      name  score strategy
# 1  Hadaly     98    Paper
# Jose chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly     98    Paper
# Hadaly chose Scissors - Edgar chose Paper
# Hadaly won
# TIE!
#      name  score  strategy
# 1  Hadaly     99  Scissors
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly     99    Paper
# Edgar chose Rock - Charles chose Scissors
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly     99    Paper
# Jose chose Rock - Hadaly chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly     99  Scissors
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly     99  Scissors
# Jose chose Scissors - Charles chose Rock
# Charles won
#      name  score  strategy
# 1  Hadaly     99  Scissors
# Hadaly chose Scissors - Edgar chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     99  Scissors
# Hadaly chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly     99     Rock
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     99     Rock
# Jose chose Scissors - Hadaly chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly     99  Scissors
# Jose chose Rock - Edgar chose Paper
# Edgar won
#      name  score  strategy
# 1  Hadaly     99  Scissors
# Jose chose Scissors - Charles chose Rock
# Charles won
#      name  score  strategy
# 1  Hadaly     99  Scissors
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly     99     Rock
# Hadaly chose Rock - Charles chose Scissors
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly    100     Rock
# Edgar chose Scissors - Charles chose Paper
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly    100     Rock
# Jose chose Rock - Hadaly chose Paper
# Hadaly won
#      name  score strategy
# 1  Hadaly    101    Paper
# Jose chose Paper - Edgar chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly    101    Paper
# Jose chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly    101    Paper
# Hadaly chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly    101     Rock
# Hadaly chose Paper - Charles chose Rock
# Hadaly won
# TIE!
#      name  score strategy
# 1  Hadaly    102    Paper
# Edgar chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly    102    Paper
# Jose chose Scissors - Hadaly chose Rock
# Hadaly won
#      name  score strategy
# 1  Hadaly    103     Rock
# Jose chose Rock - Edgar chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly    103     Rock
# Jose chose Scissors - Charles chose Rock
# Charles won
#      name  score strategy
# 1  Hadaly    103     Rock
# Hadaly chose Scissors - Edgar chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly    103  Scissors
# Hadaly chose Paper - Charles chose Paper
# TIE!
#      name  score strategy
# 1  Hadaly    103    Paper
# Edgar chose Paper - Charles chose Rock
# Edgar won
# TIE!
#      name  score strategy
# 1  Hadaly    103    Paper
# Jose chose Paper - Hadaly chose Scissors
# Hadaly won
#      name  score  strategy
# 1  Hadaly    104  Scissors
# Jose chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly    104  Scissors
# Jose chose Paper - Charles chose Rock
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly    104  Scissors
# Hadaly chose Scissors - Edgar chose Rock
# Edgar won
#      name  score  strategy
# 1  Hadaly    104  Scissors
# Hadaly chose Paper - Charles chose Scissors
# Charles won
#      name  score strategy
# 1  Hadaly    104    Paper
# Edgar chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly    104    Paper
# Jose chose Rock - Hadaly chose Scissors
# Jose won
# TIE!
#      name  score  strategy
# 1  Hadaly    104  Scissors
# Jose chose Paper - Edgar chose Paper
# TIE!
#      name  score  strategy
# 1  Hadaly    104  Scissors
# Jose chose Scissors - Charles chose Scissors
# TIE!
#      name  score  strategy
# 1  Hadaly    104  Scissors
# Hadaly chose Paper - Edgar chose Scissors
# Edgar won
#      name  score strategy
# 1  Hadaly    104    Paper
# Hadaly chose Rock - Charles chose Rock
# TIE!
#      name  score strategy
# 1  Hadaly    104     Rock
# Edgar chose Rock - Charles chose Paper
# Charles won
#      name  score strategy
# 1  Hadaly    104     Rock

# %% [markdown]
# - ### Ganador:

# %%
socialResults[socialResults.score==winnerScore]
# Out:
#      name  score strategy
# 1  Hadaly    104     Rock
