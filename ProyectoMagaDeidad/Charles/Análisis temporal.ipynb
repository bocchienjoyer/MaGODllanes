# %% [markdown]
# # Importar base de datos
# Esta base de datos contiene información sobre las obras paralizadas en el país hasta el presente año

# %%
import pandas as pd 
import os
import numpy as np

# %%
obras_df= pd.read_excel(os.path.join('data','Obras_paralizadas_new.xlsx'),header=3)
obras_df.columns=obras_df.columns.str.lower()

# %% [markdown]
# # Tratamiento de la base de datos

# %% [markdown]
# Para este trabajo solo necesitaremos trabajar con ciertas variables

# %%
list_variables= ['modalidad de ejecución de la obra', 'ano','causal de paralización','departamento']
obras_df=obras_df[list_variables].copy()

# %% [markdown]
# También necesitamos eliminar aquellas observaciones que tienen valores perdidos

# %%
obras_df.isna().sum()
# Out:
# modalidad de ejecución de la obra      0
# ano                                   48
# causal de paralización               596
# departamento                           1
# dtype: int64

# %%
obras_df.dropna(subset=['ano','causal de paralización'],inplace= True)
obras_df
# Out:
#      modalidad de ejecución de la obra     ano  \
# 0                             Contrata  2012.0
# 1                             Contrata  2012.0
# 3                             Contrata  2010.0
# 4                             Contrata  2013.0
# 5                             Contrata  2013.0
# ...                                ...     ...
# 2286            Administracion directa  2023.0
# 2288                          Contrata  2022.0
# 2289            Administracion directa  2021.0
# 2290            Administracion directa  2022.0
# 2291                          Contrata  2023.0
#
#                                  causal de paralización departamento
# 0                            Incumplimiento de contrato        CUSCO
# 1                            Incumplimiento de contrato        CUSCO
# 3     Incumplimiento del pago de valorizaciones u otros        JUNIN
# 4                            Incumplimiento de contrato       ANCASH
# 5                            Incumplimiento de contrato         PUNO
# ...                                                 ...          ...
# 2286                                   Proceso arbitral         PUNO
# 2288                                Conflictos sociales       ANCASH
# 2289                        Sin asignacion presupuestal         PUNO
# 2290          Desabastecimiento sostenido de materiales      HUANUCO
# 2291                    Falta de supervisor o inspector        JUNIN
#
# [1682 rows x 4 columns]

# %%
obras_df= obras_df.assign(case=1)
obras_df.reset_index(inplace=True)

# %% [markdown]
# # Primera pregunta: ¿cómo ha variado el número de obras paralizadas a lo largo de los años según modalidad?

# %%
obras_df['modalidad']=obras_df.loc[:,"modalidad de ejecución de la obra"]
obras_df.drop(columns=["modalidad de ejecución de la obra"],inplace=True)

# %%
obraspormodalidad=obras_df.groupby(['ano','modalidad']).agg({'case':['sum']})
obraspormodalidad.reset_index(inplace=True)
obraspormodalidad.columns=["". join (names) for names in obraspormodalidad.columns]
obraspormodalidad
# Out:
#        ano                       modalidad  casesum
# 0   2002.0                        Contrata        1
# 1   2008.0                        Contrata        4
# 2   2010.0          Administracion directa        2
# 3   2010.0                        Contrata        6
# 4   2011.0          Administracion directa        7
# 5   2011.0                        Contrata        9
# 6   2012.0          Administracion directa       15
# 7   2012.0                        Contrata       15
# 8   2013.0          Administracion directa       25
# 9   2013.0                        Contrata       21
# 10  2014.0          Administracion directa       41
# 11  2014.0                        Contrata       31
# 12  2015.0          Administracion directa       57
# 13  2015.0  Asociacion Publica Privada APP        1
# 14  2015.0                        Contrata       24
# 15  2015.0             Por nucleo ejecutor       13
# 16  2016.0          Administracion directa       75
# 17  2016.0                        Contrata       29
# 18  2016.0             Por nucleo ejecutor       12
# 19  2017.0          Administracion directa       80
# 20  2017.0                        Contrata       56
# 21  2017.0             Obras por impuestos        1
# 22  2017.0             Por nucleo ejecutor        5
# 23  2018.0          Administracion directa      117
# 24  2018.0                        Contrata       84
# 25  2019.0          Administracion directa      123
# 26  2019.0                        Contrata       68
# 27  2019.0             Por nucleo ejecutor       17
# 28  2020.0          Administracion directa      126
# 29  2020.0                        Contrata       96
# 30  2020.0             Obras por impuestos        1
# 31  2020.0             Por nucleo ejecutor        6
# 32  2021.0          Administracion directa      116
# 33  2021.0                        Contrata      107
# 34  2021.0             Por nucleo ejecutor        8
# 35  2022.0          Administracion directa      128
# 36  2022.0                        Contrata      135
# 37  2022.0             Por nucleo ejecutor        3
# 38  2023.0          Administracion directa        7
# 39  2023.0                        Contrata        8
# 40  2023.0             Por nucleo ejecutor        1
# 41  2202.0          Administracion directa        1

# %%
obraspormodalidad
# Out:
#        ano                       modalidad  casesum
# 0   2002.0                        Contrata        1
# 1   2008.0                        Contrata        4
# 2   2010.0          Administracion directa        2
# 3   2010.0                        Contrata        6
# 4   2011.0          Administracion directa        7
# 5   2011.0                        Contrata        9
# 6   2012.0          Administracion directa       15
# 7   2012.0                        Contrata       15
# 8   2013.0          Administracion directa       25
# 9   2013.0                        Contrata       21
# 10  2014.0          Administracion directa       41
# 11  2014.0                        Contrata       31
# 12  2015.0          Administracion directa       57
# 13  2015.0  Asociacion Publica Privada APP        1
# 14  2015.0                        Contrata       24
# 15  2015.0             Por nucleo ejecutor       13
# 16  2016.0          Administracion directa       75
# 17  2016.0                        Contrata       29
# 18  2016.0             Por nucleo ejecutor       12
# 19  2017.0          Administracion directa       80
# 20  2017.0                        Contrata       56
# 21  2017.0             Obras por impuestos        1
# 22  2017.0             Por nucleo ejecutor        5
# 23  2018.0          Administracion directa      117
# 24  2018.0                        Contrata       84
# 25  2019.0          Administracion directa      123
# 26  2019.0                        Contrata       68
# 27  2019.0             Por nucleo ejecutor       17
# 28  2020.0          Administracion directa      126
# 29  2020.0                        Contrata       96
# 30  2020.0             Obras por impuestos        1
# 31  2020.0             Por nucleo ejecutor        6
# 32  2021.0          Administracion directa      116
# 33  2021.0                        Contrata      107
# 34  2021.0             Por nucleo ejecutor        8
# 35  2022.0          Administracion directa      128
# 36  2022.0                        Contrata      135
# 37  2022.0             Por nucleo ejecutor        3
# 38  2023.0          Administracion directa        7
# 39  2023.0                        Contrata        8
# 40  2023.0             Por nucleo ejecutor        1
# 41  2202.0          Administracion directa        1

# %%
obraspormodalidad=obraspormodalidad[obraspormodalidad['ano']<2024]

# %%
obraspormodalidad
# Out:
#        ano                       modalidad  casesum
# 0   2002.0                        Contrata        1
# 1   2008.0                        Contrata        4
# 2   2010.0          Administracion directa        2
# 3   2010.0                        Contrata        6
# 4   2011.0          Administracion directa        7
# 5   2011.0                        Contrata        9
# 6   2012.0          Administracion directa       15
# 7   2012.0                        Contrata       15
# 8   2013.0          Administracion directa       25
# 9   2013.0                        Contrata       21
# 10  2014.0          Administracion directa       41
# 11  2014.0                        Contrata       31
# 12  2015.0          Administracion directa       57
# 13  2015.0  Asociacion Publica Privada APP        1
# 14  2015.0                        Contrata       24
# 15  2015.0             Por nucleo ejecutor       13
# 16  2016.0          Administracion directa       75
# 17  2016.0                        Contrata       29
# 18  2016.0             Por nucleo ejecutor       12
# 19  2017.0          Administracion directa       80
# 20  2017.0                        Contrata       56
# 21  2017.0             Obras por impuestos        1
# 22  2017.0             Por nucleo ejecutor        5
# 23  2018.0          Administracion directa      117
# 24  2018.0                        Contrata       84
# 25  2019.0          Administracion directa      123
# 26  2019.0                        Contrata       68
# 27  2019.0             Por nucleo ejecutor       17
# 28  2020.0          Administracion directa      126
# 29  2020.0                        Contrata       96
# 30  2020.0             Obras por impuestos        1
# 31  2020.0             Por nucleo ejecutor        6
# 32  2021.0          Administracion directa      116
# 33  2021.0                        Contrata      107
# 34  2021.0             Por nucleo ejecutor        8
# 35  2022.0          Administracion directa      128
# 36  2022.0                        Contrata      135
# 37  2022.0             Por nucleo ejecutor        3
# 38  2023.0          Administracion directa        7
# 39  2023.0                        Contrata        8
# 40  2023.0             Por nucleo ejecutor        1

# %% [markdown]
# Transformamos en formato *long* para su visualización

# %%
obras_long=obraspormodalidad.melt(id_vars=['ano','modalidad'], value_vars=['casesum'])

# %% [markdown]
# Guardamos la data para su visualización en r

# %%
obras_long.to_pickle('data/obras_long.pkl')
